# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

# %%
df=pd.read_csv('../1stweek_dataset/clothing-set.csv')

# %%
df.head()
# Out:
#    product_id          title                         product_description  \
# 0    16712992      Cutiekins  Girls Pink & White Printed Top with Shorts
# 1    21836198  Nottie Planet            Boys Printed T-shirt with Shorts
#
#    rating  ratings_count  initial_price  discount final_price currency  \
# 0     4.1            454         1999.0      70.0   "₹719.00"      INR
# 1     4.5             13          449.0      30.0   "₹314.00"      INR
#
#                                               images  ...  \
# 0  http://assets.myntassets.com/assets/images/167...  ...
# 1  http://assets.myntassets.com/assets/images/218...  ...
#
#                                      amount_of_stars what_customers_said  \
# 0  {"1_star":43,"2_stars":14,"3_stars":50,"4_star...                 NaN
# 1  {"1_star":1,"2_stars":0,"3_stars":1,"4_stars":...                 NaN
#
#                  seller_name  \
# 0  CUT███INS███IVA█████████D
# 1   MOO███ FA███ONS█████████
#
# ...

# %%
df.tail()
# Out:
#    product_id          title                         product_description  \
# 0    16712992      Cutiekins  Girls Pink & White Printed Top with Shorts
# 1    21836198  Nottie Planet            Boys Printed T-shirt with Shorts
#
#    rating  ratings_count  initial_price  discount final_price currency  \
# 0     4.1            454         1999.0      70.0   "₹719.00"      INR
# 1     4.5             13          449.0      30.0   "₹314.00"      INR
#
#                                               images  ...  \
# 0  http://assets.myntassets.com/assets/images/167...  ...
# 1  http://assets.myntassets.com/assets/images/218...  ...
#
#                                      amount_of_stars what_customers_said  \
# 0  {"1_star":43,"2_stars":14,"3_stars":50,"4_star...                 NaN
# 1  {"1_star":1,"2_stars":0,"3_stars":1,"4_stars":...                 NaN
#
#                  seller_name  \
# 0  CUT███INS███IVA█████████D
# 1   MOO███ FA███ONS█████████
#
# ...

# %%
df.shape
# Out:
# (2, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              2 non-null      int64
#  1   title                   2 non-null      object
#  2   product_description     2 non-null      object
#  3   rating                  2 non-null      float64
#  4   ratings_count           2 non-null      int64
#  5   initial_price           2 non-null      float64
#  6   discount                2 non-null      float64
#  7   final_price             2 non-null      object
#  8   currency                2 non-null      object
#  9   images                  2 non-null      object
#  10  delivery_options        2 non-null      object
#  11  product_details         2 non-null      object
#  12  breadcrumbs             2 non-null      object
#  13  product_specifications  2 non-null      object
# ...

# %%
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='object')

# %%
df.dtypes
# Out:
# product_id                  int64
# title                      object
# product_description        object
# rating                    float64
# ratings_count               int64
# initial_price             float64
# discount                  float64
# final_price                object
# currency                   object
# images                     object
# delivery_options           object
# product_details            object
# breadcrumbs                object
# product_specifications     object
# amount_of_stars            object
# what_customers_said       float64
# seller_name                object
# sizes                      object
# videos                    float64
# seller_information         object
# variations                float64
# best_offer                 object
# more_offers                object
# category                   object
# dtype: object

# %%
df.isnull().sum()
# Out:
# product_id                0
# title                     0
# product_description       0
# rating                    0
# ratings_count             0
# initial_price             0
# discount                  0
# final_price               0
# currency                  0
# images                    0
# delivery_options          0
# product_details           0
# breadcrumbs               0
# product_specifications    0
# amount_of_stars           0
# what_customers_said       2
# seller_name               0
# sizes                     0
# videos                    2
# seller_information        0
# variations                2
# best_offer                0
# more_offers               0
# category                  0
# dtype: int64

# %%
df.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_2132\3970806690.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %%
df.isnull().sum()
# Out:
# product_id                0
# title                     0
# product_description       0
# rating                    0
# ratings_count             0
# initial_price             0
# discount                  0
# final_price               0
# currency                  0
# images                    0
# delivery_options          0
# product_details           0
# breadcrumbs               0
# product_specifications    0
# amount_of_stars           0
# what_customers_said       2
# seller_name               0
# sizes                     0
# videos                    2
# seller_information        0
# variations                2
# best_offer                0
# more_offers               0
# category                  0
# dtype: int64

# %%
df.drop_duplicates(subset=['product_id'])
# Out:
#    product_id          title                         product_description  \
# 0    16712992      Cutiekins  Girls Pink & White Printed Top with Shorts
# 1    21836198  Nottie Planet            Boys Printed T-shirt with Shorts
#
#    rating  ratings_count  initial_price  discount final_price currency  \
# 0     4.1            454         1999.0      70.0   "₹719.00"      INR
# 1     4.5             13          449.0      30.0   "₹314.00"      INR
#
#                                               images  ...  \
# 0  http://assets.myntassets.com/assets/images/167...  ...
# 1  http://assets.myntassets.com/assets/images/218...  ...
#
#                                      amount_of_stars what_customers_said  \
# 0  {"1_star":43,"2_stars":14,"3_stars":50,"4_star...                 NaN
# 1  {"1_star":1,"2_stars":0,"3_stars":1,"4_stars":...                 NaN
#
#                  seller_name  \
# 0  CUT███INS███IVA█████████D
# 1   MOO███ FA███ONS█████████
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (2, 24)

# %%
selected_col=df[['final_price','initial_price','rating','title']]
selected_col.head()
# Out:
#   final_price  initial_price  rating          title
# 0   "₹719.00"         1999.0     4.1      Cutiekins
# 1   "₹314.00"          449.0     4.5  Nottie Planet

# %%
df.head()
# Out:
#    product_id          title                         product_description  \
# 0    16712992      Cutiekins  Girls Pink & White Printed Top with Shorts
# 1    21836198  Nottie Planet            Boys Printed T-shirt with Shorts
#
#    rating  ratings_count  initial_price  discount final_price currency  \
# 0     4.1            454         1999.0      70.0   "₹719.00"      INR
# 1     4.5             13          449.0      30.0   "₹314.00"      INR
#
#                                               images  ...  \
# 0  http://assets.myntassets.com/assets/images/167...  ...
# 1  http://assets.myntassets.com/assets/images/218...  ...
#
#                                      amount_of_stars what_customers_said  \
# 0  {"1_star":43,"2_stars":14,"3_stars":50,"4_star...                 NaN
# 1  {"1_star":1,"2_stars":0,"3_stars":1,"4_stars":...                 NaN
#
#                  seller_name  \
# 0  CUT███INS███IVA█████████D
# 1   MOO███ FA███ONS█████████
#
# ...

# %%
selected_rows = df[
    (df['rating'] > 4.0)
    & (df['final_price'].replace(r'[^\d.]', '', regex=True).astype(float) < 1000)
]
selected_rows.head()
selected_rows.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 selected_rows=df[(df['rating']>4.0) & (df['final_price']<1000)]
#       2 selected_rows.head()
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\pandas\core\arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
# ...
